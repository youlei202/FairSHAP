# %% [markdown]
# ## Baseline notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### baseline - experiment

# %%
from src.benchmark_methods.benchmark_methods import BenchMarkPreprocessingMethods

sota = BenchMarkPreprocessingMethods(sota_method='disparate_impact') # 'disparate_impact', 'correlation_removal', 'reweighing',
sota.run_and_save_results(save_origin=False)   # save_origin=True if you want to save the original dataset's results
# Out:
# -------------------------------------
# ---!! on german_credit dataset !!---
# -------------------------------------
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# diff_count: 1420
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# diff_count: 1633
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# diff_count: 1677
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# diff_count: 1670
# -------------------------------------
# ...

# %%
from src.experiments.fairshap_all_values import FairSHAP

fairshap = FairSHAP(threshold=0.1, matching_method='NN', fairshap_base='DR')
fairshap.run_and_save_results()
# Out:
# -------------------------------------
# ---!! on german_credit dataset !!---
# -------------------------------------
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 1. Split the german_credit dataset into majority group and minority group according to the number of sensitive attribute, besides split by label 0 and label 1
# X_train_majority_label0 shape: (391, 26)
# X_train_majority_label1 shape: (152, 26)
# X_train_minority_label0 shape: (168, 26)
# X_train_minority_label1 shape: (89, 26)
# 2. 初始化FairnessExplainer
# --------接下来先对minority group进行修改--------
# 3(a). 将X_train_minority_label0与X_train_majority_label0进行匹配
# ...

# %%
import numpy as np
from scipy.stats import wasserstein_distance

def compute_wasserstein_fidelity(original_data: np.ndarray, augmented_data: np.ndarray):
    assert original_data.shape == augmented_data.shape, "数据形状必须匹配"
    
    num_features = original_data.shape[1]
    wasserstein_scores = [
        wasserstein_distance(original_data[:, i], augmented_data[:, i]) 
        for i in range(num_features)
    ]
    
    return np.array(wasserstein_scores)

# 示例
original_data = np.random.normal(0, 1, (1000, 5))
augmented_data = original_data + np.random.normal(0, 0.1, (1000, 5))  # 添加轻微噪声

wasserstein_scores = compute_wasserstein_fidelity(original_data, augmented_data)
print("Wasserstein Fidelity per feature:", wasserstein_scores)
print("Mean Fidelity:", np.mean(wasserstein_scores))
# Out:
# Wasserstein Fidelity per feature: [0.01732239 0.01691976 0.01760005 0.01461311 0.01518828]
# Mean Fidelity: 0.016328715336750656
