# %% [markdown]
# ## Ablation study

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from src.ablation_study.ablation_study import AblationStudy
from xgboost import XGBClassifier
model = XGBClassifier()
ablation = AblationStudy(model=model)
ablation.run_ablation_study_1()
# Out:
# -------------------------------------
# ---!! on german_credit dataset !!---
# -------------------------------------
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(800, 26)
# X_change 与 X_base 有3970个不同的值
# 要替换3000个值
# 有2497个值相同，所以不能被替换
# 实际替换了503个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(800, 26)
# X_change 与 X_base 有4038个不同的值
# 要替换3000个值
# 有2474个值相同，所以不能被替换
# 实际替换了526个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(800, 26)
# X_change 与 X_base 有3989个不同的值
# 要替换3000个值
# 有2463个值相同，所以不能被替换
# 实际替换了537个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(800, 26)
# X_change 与 X_base 有3990个不同的值
# 要替换3000个值
# 有2448个值相同，所以不能被替换
# 实际替换了552个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(800, 26)
# X_change 与 X_base 有4029个不同的值
# 要替换3000个值
# 有2455个值相同，所以不能被替换
# 实际替换了545个值
# ✅ german_credit 处理后结果已保存到 saved_results/ablation_study\ablation_study_1.csv
# -------------------------------------
# ---!! on compas dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(5771, 18)
# X_change 与 X_base 有13573个不同的值
# 要替换8000个值
# 有7023个值相同，所以不能被替换
# 实际替换了977个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(5771, 18)
# X_change 与 X_base 有13338个不同的值
# 要替换8000个值
# 有6973个值相同，所以不能被替换
# 实际替换了1027个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(5771, 18)
# X_change 与 X_base 有13572个不同的值
# 要替换8000个值
# 有6996个值相同，所以不能被替换
# 实际替换了1004个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(5771, 18)
# X_change 与 X_base 有13599个不同的值
# 要替换8000个值
# 有6976个值相同，所以不能被替换
# 实际替换了1024个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(5772, 18)
# X_change 与 X_base 有13479个不同的值
# 要替换8000个值
# 有6945个值相同，所以不能被替换
# 实际替换了1055个值
# ✅ compas 处理后结果已保存到 saved_results/ablation_study\ablation_study_1.csv
# -------------------------------------
# ---!! on compas4race dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(4920, 13)
# X_change 与 X_base 有10071个不同的值
# 要替换8000个值
# 有6821个值相同，所以不能被替换
# 实际替换了1179个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(4920, 13)
# X_change 与 X_base 有10101个不同的值
# 要替换8000个值
# 有6777个值相同，所以不能被替换
# 实际替换了1223个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(4920, 13)
# X_change 与 X_base 有9943个不同的值
# 要替换8000个值
# 有6825个值相同，所以不能被替换
# 实际替换了1175个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(4920, 13)
# X_change 与 X_base 有10040个不同的值
# 要替换8000个值
# 有6813个值相同，所以不能被替换
# 实际替换了1187个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑8000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(4920, 13)
# X_change 与 X_base 有10054个不同的值
# 要替换8000个值
# 有6814个值相同，所以不能被替换
# 实际替换了1186个值
# ✅ compas4race 处理后结果已保存到 saved_results/ablation_study\ablation_study_1.csv
# -------------------------------------
# ---!! on adult dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑90000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(26048, 106)
# X_change 与 X_base 有122460个不同的值
# 要替换90000个值
# 有86141个值相同，所以不能被替换
# 实际替换了3859个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑90000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(26049, 106)
# X_change 与 X_base 有122375个不同的值
# 要替换90000个值
# 有86074个值相同，所以不能被替换
# 实际替换了3926个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑90000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(26049, 106)
# X_change 与 X_base 有121757个不同的值
# 要替换90000个值
# 有86080个值相同，所以不能被替换
# 实际替换了3920个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑90000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(26049, 106)
# X_change 与 X_base 有122998个不同的值
# 要替换90000个值
# 有86118个值相同，所以不能被替换
# 实际替换了3882个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑90000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(26049, 106)
# X_change 与 X_base 有121953个不同的值
# 要替换90000个值
# 有86066个值相同，所以不能被替换
# 实际替换了3934个值
# ✅ adult 处理后结果已保存到 saved_results/ablation_study\ablation_study_1.csv
# -------------------------------------
# ---!! on default_credit dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑5000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(24000, 90)
# X_change 与 X_base 有341104个不同的值
# 要替换5000个值
# 有4164个值相同，所以不能被替换
# 实际替换了836个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑5000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(24000, 90)
# X_change 与 X_base 有342257个不同的值
# 要替换5000个值
# 有4173个值相同，所以不能被替换
# 实际替换了827个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑5000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(24000, 90)
# X_change 与 X_base 有341527个不同的值
# 要替换5000个值
# 有4191个值相同，所以不能被替换
# 实际替换了809个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑5000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(24000, 90)
# X_change 与 X_base 有341194个不同的值
# 要替换5000个值
# 有4178个值相同，所以不能被替换
# 实际替换了822个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑5000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(24000, 90)
# X_change 与 X_base 有341002个不同的值
# 要替换5000个值
# 有4233个值相同，所以不能被替换
# 实际替换了767个值
# ✅ default_credit 处理后结果已保存到 saved_results/ablation_study\ablation_study_1.csv
# -------------------------------------
# ---!! on census_income_kdd dataset !!---
# -------------------------------------
# age                                           0
# workclass                                     0
# industry_code                                 0
# occupation_code                               0
# education                                     0
# wage_per_hour                                 0
# enrolled_in_edu_inst_last_wk                  0
# marital_status                                0
# major_industry_code                           0
# major_occupation_code                         0
# race                                          0
# hispanic_origin                               0
# sex                                           0
# member_of_a_labour_union                      0
# reason_for_unemployment                       0
# employment_status                             0
# capital_gains                                 0
# capital_losses                                0
# dividend_from_stocks                          0
# tax_filler_status                             0
# region_of_previous_residence                  0
# state_of_previous_residence                   0
# detailed_household_and_family_stat            0
# detailed_household_summary_in_household       0
# instance_weight                               0
# migration_code_change_in_msa                  0
# migration_code_change_in_reg                  0
# migration_code_move_within_reg                0
# live_in_this_house_1_year_ag                  0
# migration_prev_res_in_sunbelt                 0
# num_persons_worked_for_employer               0
# family_members_under_18                       0
# country_of_birth_father                       0
# country_of_birth_mother                       0
# country_of_birth_self                         0
# citizenship                                   0
# own_business_or_self_employed                 0
# fill_inc_questionnaire_for_veteran's_admin    0
# veterans_benefits                             0
# weeks_worked_in_year                          0
# year                                          0
# class                                         0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑200000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(22886, 505)
# X_change 与 X_base 有185196个不同的值
# 要替换200000个值
# 有196904个值相同，所以不能被替换
# 实际替换了3096个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑200000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(22886, 505)
# X_change 与 X_base 有185401个不同的值
# 要替换200000个值
# 有196802个值相同，所以不能被替换
# 实际替换了3198个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑200000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(22886, 505)
# X_change 与 X_base 有185502个不同的值
# 要替换200000个值
# 有196809个值相同，所以不能被替换
# 实际替换了3191个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑200000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(22887, 505)
# X_change 与 X_base 有185634个不同的值
# 要替换200000个值
# 有196896个值相同，所以不能被替换
# 实际替换了3104个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑200000个位置，把这些位置的值替换成X_base里的值
# X_change shape:(22887, 505)
# X_change 与 X_base 有185393个不同的值
# 要替换200000个值
# 有196825个值相同，所以不能被替换
# 实际替换了3175个值
# ✅ census_income_kdd 处理后结果已保存到 saved_results/ablation_study\ablation_study_1.csv

# %%
ablation.run_ablation_study_2()
# Out:
# -------------------------------------
# ---!! on german_credit dataset !!---
# -------------------------------------
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑323个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 323 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 323 个 sex 值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑323个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 323 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 323 个 sex 值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑323个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 323 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 323 个 sex 值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑323个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 323 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 323 个 sex 值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑323个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 323 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 323 个 sex 值
# ✅ german_credit 处理后结果已保存到 saved_results/ablation_study\ablation_study_2.csv
# -------------------------------------
# ---!! on compas dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑1175个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 1175 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 1175 个 sex 值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑1175个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 1175 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 1175 个 sex 值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑1175个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 1175 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 1175 个 sex 值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑1175个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 1175 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 1175 个 sex 值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑1175个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 1175 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 1175 个 sex 值
# ✅ compas 处理后结果已保存到 saved_results/ablation_study\ablation_study_2.csv
# -------------------------------------
# ---!! on compas4race dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑907个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 race 列中挑 907 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 907 个 race 值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑907个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 race 列中挑 907 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 907 个 race 值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑907个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 race 列中挑 907 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 907 个 race 值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑907个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 race 列中挑 907 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 907 个 race 值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑907个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 race 列中挑 907 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 907 个 race 值
# ✅ compas4race 处理后结果已保存到 saved_results/ablation_study\ablation_study_2.csv
# -------------------------------------
# ---!! on adult dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3361个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3361 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3361 个 sex 值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3361个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3361 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3361 个 sex 值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3361个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3361 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3361 个 sex 值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3361个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3361 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3361 个 sex 值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3361个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3361 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3361 个 sex 值
# ✅ adult 处理后结果已保存到 saved_results/ablation_study\ablation_study_2.csv
# -------------------------------------
# ---!! on default_credit dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑888个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 888 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 888 个 sex 值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑888个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 888 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 888 个 sex 值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑888个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 888 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 888 个 sex 值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑888个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 888 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 888 个 sex 值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑888个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 888 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 888 个 sex 值
# ✅ default_credit 处理后结果已保存到 saved_results/ablation_study\ablation_study_2.csv
# -------------------------------------
# ---!! on census_income_kdd dataset !!---
# -------------------------------------
# age                                           0
# workclass                                     0
# industry_code                                 0
# occupation_code                               0
# education                                     0
# wage_per_hour                                 0
# enrolled_in_edu_inst_last_wk                  0
# marital_status                                0
# major_industry_code                           0
# major_occupation_code                         0
# race                                          0
# hispanic_origin                               0
# sex                                           0
# member_of_a_labour_union                      0
# reason_for_unemployment                       0
# employment_status                             0
# capital_gains                                 0
# capital_losses                                0
# dividend_from_stocks                          0
# tax_filler_status                             0
# region_of_previous_residence                  0
# state_of_previous_residence                   0
# detailed_household_and_family_stat            0
# detailed_household_summary_in_household       0
# instance_weight                               0
# migration_code_change_in_msa                  0
# migration_code_change_in_reg                  0
# migration_code_move_within_reg                0
# live_in_this_house_1_year_ag                  0
# migration_prev_res_in_sunbelt                 0
# num_persons_worked_for_employer               0
# family_members_under_18                       0
# country_of_birth_father                       0
# country_of_birth_mother                       0
# country_of_birth_self                         0
# citizenship                                   0
# own_business_or_self_employed                 0
# fill_inc_questionnaire_for_veteran's_admin    0
# veterans_benefits                             0
# weeks_worked_in_year                          0
# year                                          0
# class                                         0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3236个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3236 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3236 个 sex 值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3236个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3236 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3236 个 sex 值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3236个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3236 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3236 个 sex 值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3236个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3236 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3236 个 sex 值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 在X_change的所有值中挑3236个位置的敏感属性，把这些位置的值从1替换成0，从0替换成1
# 在 X_change 的 sex 列中挑 3236 个位置，将 1 替换为 0，将 0 替换为 1
# 成功修改了 3236 个 sex 值
# ✅ census_income_kdd 处理后结果已保存到 saved_results/ablation_study\ablation_study_2.csv

# %%
from src.ablation_study.ablation_study import AblationStudy
from xgboost import XGBClassifier
model = XGBClassifier()
ablation = AblationStudy(model=model)
ablation.run_ablation_study_3()
# Out:
# -------------------------------------
# ---!! on german_credit dataset !!---
# -------------------------------------
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 要替换1000个值
# 实际替换了340个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 要替换1000个值
# 实际替换了317个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 要替换1000个值
# 实际替换了282个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 要替换1000个值
# 实际替换了333个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 要替换1000个值
# 实际替换了318个值
# ✅ german_credit 处理后结果已保存到 saved_results/ablation_study\ablation_study_3.csv
# -------------------------------------
# ---!! on compas dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 要替换4000个值
# 实际替换了1270个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 要替换4000个值
# 实际替换了1258个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 要替换4000个值
# 实际替换了1288个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 要替换4000个值
# 实际替换了1297个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 要替换4000个值
# 实际替换了1258个值
# ✅ compas 处理后结果已保存到 saved_results/ablation_study\ablation_study_3.csv
# -------------------------------------
# ---!! on compas4race dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 要替换3000个值
# 实际替换了1174个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 要替换3000个值
# 实际替换了1168个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 要替换3000个值
# 实际替换了1224个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 要替换3000个值
# 实际替换了1154个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 要替换3000个值
# 实际替换了1174个值
# ✅ compas4race 处理后结果已保存到 saved_results/ablation_study\ablation_study_3.csv
# -------------------------------------
# ---!! on adult dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 要替换30000个值
# 实际替换了3210个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 要替换30000个值
# 实际替换了3260个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 要替换30000个值
# 实际替换了3144个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 要替换30000个值
# 实际替换了3201个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 要替换30000个值
# 实际替换了3327个值
# ✅ adult 处理后结果已保存到 saved_results/ablation_study\ablation_study_3.csv
# -------------------------------------
# ---!! on default_credit dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 要替换2000个值
# 实际替换了530个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 要替换2000个值
# 实际替换了478个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 要替换2000个值
# 实际替换了529个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 要替换2000个值
# 实际替换了508个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 要替换2000个值
# 实际替换了536个值
# ✅ default_credit 处理后结果已保存到 saved_results/ablation_study\ablation_study_3.csv
# -------------------------------------
# ---!! on census_income_kdd dataset !!---
# -------------------------------------
# age                                           0
# workclass                                     0
# industry_code                                 0
# occupation_code                               0
# education                                     0
# wage_per_hour                                 0
# enrolled_in_edu_inst_last_wk                  0
# marital_status                                0
# major_industry_code                           0
# major_occupation_code                         0
# race                                          0
# hispanic_origin                               0
# sex                                           0
# member_of_a_labour_union                      0
# reason_for_unemployment                       0
# employment_status                             0
# capital_gains                                 0
# capital_losses                                0
# dividend_from_stocks                          0
# tax_filler_status                             0
# region_of_previous_residence                  0
# state_of_previous_residence                   0
# detailed_household_and_family_stat            0
# detailed_household_summary_in_household       0
# instance_weight                               0
# migration_code_change_in_msa                  0
# migration_code_change_in_reg                  0
# migration_code_move_within_reg                0
# live_in_this_house_1_year_ag                  0
# migration_prev_res_in_sunbelt                 0
# num_persons_worked_for_employer               0
# family_members_under_18                       0
# country_of_birth_father                       0
# country_of_birth_mother                       0
# country_of_birth_self                         0
# citizenship                                   0
# own_business_or_self_employed                 0
# fill_inc_questionnaire_for_veteran's_admin    0
# veterans_benefits                             0
# weeks_worked_in_year                          0
# year                                          0
# class                                         0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# 要替换50000个值
# 实际替换了3281个值
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# 要替换50000个值
# 实际替换了3261个值
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# 要替换50000个值
# 实际替换了3267个值
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# 要替换50000个值
# 实际替换了3129个值
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# 要替换50000个值
# 实际替换了3312个值
# ✅ census_income_kdd 处理后结果已保存到 saved_results/ablation_study\ablation_study_3.csv
