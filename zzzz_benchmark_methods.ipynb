# %% [markdown]
# ## Baseline notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### baseline - experiment

# %%
from src.benchmark_methods import BenchMarkPreprocessingMethods

sota = BenchMarkPreprocessingMethods(sota_method='correlation_removal') # 'disparate_impact', 'correlation_removal', 'reweighing',
sota.run_and_save_results(save_origin=False)   # save_origin=True if you want to save the original dataset's results
# Out:
# -------------------------------------
# ---!! on german_credit dataset !!---
# -------------------------------------
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# diff_count: 20000
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# diff_count: 20000
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# diff_count: 20000
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# diff_count: 20000
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# diff_count: 20000
# ✅ german_credit 处理后结果已保存到 saved_results/sota_results\correlation_removal_results.csv
# -------------------------------------
# ---!! on compas dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# diff_count: 93437
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# diff_count: 93482
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# diff_count: 93435
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# diff_count: 98107
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# diff_count: 98124
# ✅ compas 处理后结果已保存到 saved_results/sota_results\correlation_removal_results.csv
# -------------------------------------
# ---!! on compas4race dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# diff_count: 61085
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# diff_count: 61054
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# diff_count: 58100
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# diff_count: 61087
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# diff_count: 58112
# ✅ compas4race 处理后结果已保存到 saved_results/sota_results\correlation_removal_results.csv
# -------------------------------------
# ---!! on adult dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# diff_count: 2708992
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# diff_count: 2735145
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# diff_count: 2735145
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# diff_count: 2735145
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# diff_count: 2735145
# ✅ adult 处理后结果已保存到 saved_results/sota_results\correlation_removal_results.csv
# -------------------------------------
# ---!! on default_credit dataset !!---
# -------------------------------------
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# diff_count: 2112000
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# diff_count: 2136000
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# diff_count: 2136000
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# diff_count: 2112000
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# diff_count: 2136000
# ✅ default_credit 处理后结果已保存到 saved_results/sota_results\correlation_removal_results.csv
# -------------------------------------
# ---!! on census_income_kdd dataset !!---
# -------------------------------------
# age                                           0
# workclass                                     0
# industry_code                                 0
# occupation_code                               0
# education                                     0
# wage_per_hour                                 0
# enrolled_in_edu_inst_last_wk                  0
# marital_status                                0
# major_industry_code                           0
# major_occupation_code                         0
# race                                          0
# hispanic_origin                               0
# sex                                           0
# member_of_a_labour_union                      0
# reason_for_unemployment                       0
# employment_status                             0
# capital_gains                                 0
# capital_losses                                0
# dividend_from_stocks                          0
# tax_filler_status                             0
# region_of_previous_residence                  0
# state_of_previous_residence                   0
# detailed_household_and_family_stat            0
# detailed_household_summary_in_household       0
# instance_weight                               0
# migration_code_change_in_msa                  0
# migration_code_change_in_reg                  0
# migration_code_move_within_reg                0
# live_in_this_house_1_year_ag                  0
# migration_prev_res_in_sunbelt                 0
# num_persons_worked_for_employer               0
# family_members_under_18                       0
# country_of_birth_father                       0
# country_of_birth_mother                       0
# country_of_birth_self                         0
# citizenship                                   0
# own_business_or_self_employed                 0
# fill_inc_questionnaire_for_veteran's_admin    0
# veterans_benefits                             0
# weeks_worked_in_year                          0
# year                                          0
# class                                         0
# dtype: int64
# -------------------------------------
# -------------0th fold----------------
# -------------------------------------
# diff_count: 11282798
# -------------------------------------
# -------------1th fold----------------
# -------------------------------------
# diff_count: 11328570
# -------------------------------------
# -------------2th fold----------------
# -------------------------------------
# diff_count: 11305684
# -------------------------------------
# -------------3th fold----------------
# -------------------------------------
# diff_count: 11329065
# -------------------------------------
# -------------4th fold----------------
# -------------------------------------
# diff_count: 11329065
# ✅ census_income_kdd 处理后结果已保存到 saved_results/sota_results\correlation_removal_results.csv
